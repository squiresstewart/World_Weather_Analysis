# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


# Import the datetime module from the datetime library.
from datetime import datetime
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
(cities)
# Out:
# ['rikitea',
#  'vestmannaeyjar',
#  'cap malheureux',
#  'iberia',
#  'bluff',
#  'dolores',
#  'sao filipe',
#  'bethel',
#  'karratha',
#  'castro',
#  'vardo',
#  'roebourne',
#  'east london',
#  'cape town',
#  'westport',
#  'bredasdorp',
#  'mataura',
#  'kruisfontein',
#  'moerai',
#  'kapaa',
#  'atuona',
#  'montepuez',
#  'lavrentiya',
#  'cairns',
#  'severo-kurilsk',
#  'kahului',
#  'kajaani',
#  'yuganets',
#  'butaritari',
#  'esperance',
#  'tshikapa',
#  'attawapiskat',
#  'viedma',
#  'gornyy',
#  'coahuayana',
#  'qaanaaq',
#  'klaksvik',
#  'constitucion',
#  'mar del plata',
#  'jamestown',
#  'tyukhtet',
#  'kununurra',
#  'pisco',
#  'arraial do cabo',
#  'saint george',
#  'prieska',
#  'hobart',
#  'chapais',
#  'kasongo',
#  'klyuchi',
#  'vaitupu',
#  'hilo',
#  'pangnirtung',
#  'udachnyy',
#  'jacareacanga',
#  'dabat',
#  'san cristobal',
#  'tahta',
#  'terney',
#  'hermanus',
#  'killybegs',
#  'mariinsk',
#  'port hardy',
#  'tasiilaq',
#  'rincon',
#  'new norfolk',
#  'punta arenas',
#  'druzhba',
#  'maryborough',
#  'sao miguel do araguaia',
#  'ushuaia',
#  'kiunga',
#  'norman wells',
#  'lodwar',
#  'carnarvon',
#  'nikolskoye',
#  'cayenne',
#  'thompson',
#  'namtsy',
#  'barentsburg',
#  'hanzhong',
#  'faya',
#  'bindi',
#  'umzimvubu',
#  'gigmoto',
#  'vaini',
#  'broome',
#  'dholka',
#  'olafsvik',
#  'biak',
#  'mys shmidta',
#  'geraldton',
#  'dukat',
#  'bandarbeyla',
#  'gorin',
#  'albany',
#  'cherskiy',
#  'sampues',
#  'port alfred',
#  'riyadh',
#  'taolanaro',
#  'khorinsk',
#  'puerto ayora',
#  'chute-aux-outardes',
#  'chagda',
#  'ruatoria',
#  'nyurba',
#  'buala',
#  'dwarka',
#  'busselton',
#  'tuktoyaktuk',
#  'lata',
#  'sabzevar',
#  'pevek',
#  'illoqqortoormiut',
#  'barreirinha',
#  'westerland',
#  'saint anthony',
#  'georgetown',
#  'boulsa',
#  'chikhli',
#  'hithadhoo',
#  'chernyshevskiy',
#  'kasempa',
#  'ahipara',
#  'pochutla',
#  'synya',
#  'kodiak',
#  'fairbanks',
#  'chuy',
#  'ostrovnoy',
#  'bengkulu',
#  'iqaluit',
#  'camocim',
#  'hofn',
#  'mount isa',
#  'talnakh',
#  'lebu',
#  'malakal',
#  'xiamen',
#  'salta',
#  'amahai',
#  'makakilo city',
#  'avarua',
#  'chornobayivka',
#  'airai',
#  'sibolga',
#  'tabiauea',
#  'rawson',
#  'japura',
#  'yellowknife',
#  'barrow',
#  'natchez',
#  'okhotsk',
#  'qasigiannguit',
#  'torbay',
#  'ilulissat',
#  'moussoro',
#  'talaya',
#  'whitianga',
#  'sokol',
#  'saint-francois',
#  'cabatuan',
#  'raudeberg',
#  'mastic beach',
#  'guantanamo',
#  'leningradskiy',
#  'sokoto',
#  'nizhneyansk',
#  'deniliquin',
#  'ketchikan',
#  'cidreira',
#  'khatanga',
#  'morondava',
#  'corum',
#  'slave lake',
#  'port elizabeth',
#  'dikson',
#  'nanakuli',
#  'bambous virieux',
#  'uyuni',
#  'nantucket',
#  'tiksi',
#  'solnechnogorsk',
#  'naze',
#  'fortuna',
#  'ulaangom',
#  'antofagasta',
#  'moroni',
#  'dingzhou',
#  'san rafael',
#  'verkh-usugli',
#  'nadapuram',
#  'mecca',
#  'hualmay',
#  'igarka',
#  'anchorage',
#  'miraflores',
#  'la paz',
#  'upernavik',
#  'ribeira grande',
#  'bilma',
#  'cabo san lucas',
#  'abu samrah',
#  'batagay-alyta',
#  'kaeo',
#  'tecolutla',
#  'huarmey',
#  'sept-iles',
#  'kudahuvadhoo',
#  'hambantota',
#  'champerico',
#  'hami',
#  'sorland',
#  'moundou',
#  'yuanping',
#  'hasaki',
#  'amderma',
#  'belushya guba',
#  'tabas',
#  'akyab',
#  'kargopol',
#  'dharchula',
#  'jaguarao',
#  'longyearbyen',
#  'kunda',
#  'bonavista',
#  'ewa beach',
#  'gangotri',
#  'verkhnevilyuysk',
#  'osoyoos',
#  'warrington',
#  'lompoc',
#  'kaitangata',
#  'bayangol',
#  'zenzeli',
#  'stornoway',
#  'kavieng',
#  'novikovo',
#  'zarubino',
#  'poum',
#  'chokurdakh',
#  'veraval',
#  'zhengjiatun',
#  'krasnoselkup',
#  'yarovoye',
#  'koungou',
#  'anadyr',
#  'jashpurnagar',
#  'salalah',
#  'xiongzhou',
#  'tarm',
#  'acari',
#  'ancud',
#  'nelson bay',
#  'souillac',
#  'sur',
#  'luderitz',
#  'muros',
#  'sentyabrskiy',
#  'tonota',
#  'porto-vecchio',
#  'santa isabel do rio negro',
#  'port said',
#  'faanui',
#  'koslan',
#  'sitka',
#  'shitanjing',
#  'bourail',
#  'namibe',
#  'tabialan',
#  'labutta',
#  'nanortalik',
#  'ossora',
#  'inhambane',
#  'tilichiki',
#  'aklavik',
#  'saskylakh',
#  'ponta do sol',
#  'yining',
#  'ambilobe',
#  'bodden town',
#  'kralendijk',
#  'mahebourg',
#  'luba',
#  'guerrero negro',
#  'stonewall',
#  'poronaysk',
#  'avera',
#  'tessalit',
#  'santa eulalia del rio',
#  'pacific grove',
#  'cambe',
#  'novovasylivka',
#  'harqalah',
#  'luganville',
#  'victoria',
#  'abeche',
#  'camacupa',
#  'port-gentil',
#  'uige',
#  'qaqortoq',
#  'eyl',
#  'mackay',
#  'gushi',
#  'dingle',
#  'port blair',
#  'lesnoy',
#  'nabire',
#  'talovaya',
#  'mana',
#  'tromso',
#  'traverse city',
#  'antalaha',
#  'northam',
#  'roma',
#  'bathsheba',
#  'gizo',
#  'bad doberan',
#  'troitsko-pechorsk',
#  'babanusah',
#  'campbell river',
#  'kieta',
#  'aginskoye',
#  'karlskoga',
#  'neustadt',
#  'benguela',
#  'corrente',
#  'saint-philippe',
#  'grand river south east',
#  'bakchar',
#  'xinmin',
#  'tenenkou',
#  'prien',
#  'turukhansk',
#  'hirara',
#  'kutum',
#  'dunedin',
#  'san matias',
#  'ternate',
#  'lere',
#  'vestmanna',
#  'tsihombe',
#  'saleaula',
#  'iracoubo',
#  'manzanillo',
#  'ariquemes',
#  'vieux-habitants',
#  'manta',
#  'najran',
#  'sao felix do xingu',
#  'isiro',
#  'mentok',
#  'portland',
#  'brae',
#  'aljezur',
#  'miri',
#  'gondanglegi',
#  'kurilsk',
#  'papasquiaro',
#  'ludvika',
#  'aykhal',
#  'kholm-zhirkovskiy',
#  'ferme-neuve',
#  'sinnamary',
#  'lorengau',
#  'plettenberg bay',
#  'ribeira brava',
#  'sembakung',
#  'punakha',
#  'tahe',
#  'palmer',
#  'auxerre',
#  'bilibino',
#  'caravelas',
#  'jijiang',
#  'yar-sale',
#  'kawalu',
#  'tapaua',
#  'provideniya',
#  'wattegama',
#  'sao joao da barra',
#  'awbari',
#  'los llanos de aridane',
#  'dossor',
#  'vila velha',
#  'ngunguru',
#  'banjar',
#  'komsomolskiy',
#  'arman',
#  'presidencia roque saenz pena',
#  'mangrol',
#  'camana',
#  'margate',
#  'beringovskiy',
#  'valparaiso',
#  'garowe',
#  'pringsewu',
#  'mujiayingzi',
#  'itarema',
#  'condoto',
#  'acajutla',
#  'abu kamal',
#  'shihezi',
#  'burgos',
#  'isangel',
#  'xining',
#  'ouesso',
#  'chicama',
#  'tumannyy',
#  'lagoa',
#  'puerto leguizamo',
#  'gladstone',
#  'yulara',
#  'alofi',
#  'concepcion del oro',
#  'praya',
#  'touros',
#  'oga',
#  'sovetskaya',
#  'mungaa',
#  'dibaya',
#  'careiro da varzea',
#  'baykit',
#  'burnie',
#  'wanning',
#  'tiarei',
#  'shingu',
#  'nagato',
#  'teya',
#  'marcona',
#  'paka',
#  'rio grande',
#  'dhidhdhoo',
#  'muli',
#  'samarinda',
#  'hikari',
#  'poggibonsi',
#  'bulgan',
#  'juifang',
#  'arroyo',
#  'kazanskoye',
#  'mariinskiy posad',
#  'kerman',
#  'kirakira',
#  'sisimiut',
#  'kapoeta',
#  'clyde river',
#  'lodja',
#  'jinchang',
#  'doctor pedro p. pena',
#  'revelganj',
#  'macatbong',
#  'moyale',
#  'madridejos',
#  'zhongshu',
#  'puerto carreno',
#  'itupiranga',
#  'hamilton',
#  'la rioja',
#  'half moon bay',
#  'launceston',
#  'teknaf',
#  'seymchan',
#  'port hedland',
#  'jiuquan',
#  'upata',
#  'porto novo',
#  'bealanana',
#  'sioux lookout',
#  'tula',
#  'montrose',
#  'toumodi',
#  'galesong',
#  'yambio',
#  'korla',
#  'wilmington',
#  'strezhevoy',
#  'riyaq',
#  'fukue',
#  'hargeysa',
#  'esso',
#  'chippewa falls',
#  'hermosillo',
#  'bayan',
#  'kavaratti',
#  'richards bay',
#  'znamenskoye',
#  'alcala de henares',
#  'trelew',
#  'cazaje',
#  'muisne',
#  'codrington',
#  'usakos',
#  'szczecinek',
#  'yashkul',
#  'te anau',
#  'pleasant point',
#  'nauen',
#  'san martin',
#  'praia',
#  'mocajuba',
#  'pascagoula',
#  'salo',
#  'semiletka',
#  'navapur',
#  'longyan',
#  'walvis bay',
#  'warqla',
#  'sechura',
#  'khandyga',
#  'blagoyevo',
#  'bodaybo',
#  'talas',
#  'yola',
#  'micheweni',
#  'albion',
#  'port augusta',
#  'saveh',
#  'samusu',
#  'texas city',
#  'anahuac',
#  'chara',
#  'louisbourg',
#  'san quintin',
#  'phangnga',
#  'pemba',
#  'dianopolis',
#  'barcelos',
#  'tucuman',
#  'soeng sang',
#  'kanth',
#  'amapa',
#  'bur gabo',
#  'bara',
#  'yusva',
#  'san patricio',
#  'honolulu',
#  'tuatapere',
#  'mahajanga',
#  'vitoria da conquista',
#  'two rivers',
#  'bogotol',
#  'griffith',
#  'ahuimanu',
#  'bindura',
#  'independencia',
#  'auki',
#  'aksu',
#  'fakel',
#  'imeni poliny osipenko',
#  'umm jarr',
#  'alice springs',
#  'srednekolymsk',
#  'smolenka',
#  'rio de jesus',
#  'ciudad bolivar',
#  'grand centre',
#  'cabra',
#  'skjervoy',
#  'redlands',
#  'bondo',
#  'barmer',
#  'lasa',
#  'samalaeulu',
#  'south river',
#  'vryburg',
#  'obidos',
#  'tulum',
#  'sayyan',
#  'alekseyevsk',
#  'nome',
#  'bodo',
#  'kemijarvi',
#  'roald',
#  'kloulklubed',
#  'lokosovo',
#  'hokitika',
#  'miramar',
#  'malm',
#  'yanchukan',
#  'maniitsoq',
#  'qeshm',
#  'ust-nera',
#  'dudinka',
#  'fierze',
#  'flin flon',
#  'cervo',
#  'ponta delgada',
#  'hobyo',
#  'perth',
#  'karamay',
#  'bubaque',
#  'nishihara',
#  'freeport',
#  'sertolovo',
#  'kamenka',
#  'caceres',
#  'tynda',
#  'sakaiminato',
#  'thinadhoo',
#  'enshi',
#  'nasrullaganj',
#  'pandan',
#  'manica',
#  'lidkoping',
#  'jaguaruna',
#  'bowen',
#  'saldanha',
#  'villarrica',
#  'umm lajj',
#  'coquimbo',
#  'zakopane',
#  'nakhon thai',
#  'mordovo',
#  'sinop',
#  'prigorodnyy',
#  'taltal',
#  'boffa',
#  'peleduy',
#  'thunder bay',
#  'necochea',
#  'zakamensk',
#  'dongsheng',
#  'rio de janeiro',
#  'bosaso',
#  'vila franca do campo',
#  'booue',
#  'mantua',
#  'the valley',
#  'caucaia',
#  'shubarshi',
#  'atbasar',
#  'trairi',
#  'port macquarie',
#  'saint joseph',
#  'jati',
#  'oranjemund',
#  'soyo',
#  'jalingo',
#  'kiomboi',
#  'mehamn',
#  'fort nelson',
#  'athabasca',
#  'makhachkala',
#  'canakkale',
#  'nizwa',
#  'lazaro cardenas',
#  'fulitun',
#  'ayabaca',
#  'paamiut',
#  'chiredzi',
#  'nouadhibou',
#  'cockburn town',
#  'katsuura',
#  'hervey bay',
#  'sokolovo',
#  'rancho palos verdes',
#  'taoudenni',
#  'zlatoustovsk',
#  'usinsk',
#  'katangli',
#  'maralal',
#  'daru',
#  'sabha',
#  'inderborskiy',
#  'san juan',
#  'sarangani',
#  'newport',
#  'miyako',
#  'rocha',
#  'colac',
#  'nago',
#  'mizpe ramon',
#  'fez',
#  'kankon',
#  'mao',
#  'mandurah',
#  'kasane',
#  'camacha',
#  'ozernovskiy',
#  'abu dhabi',
#  'coromandel',
#  'canto do buriti',
#  'ambon',
#  'kantabanji',
#  'narsaq',
#  'ulladulla',
#  'bac lieu',
#  'buenos aires',
#  'piranshahr',
#  'banepa',
#  'bardiyah',
#  'morant bay',
#  'ardabil',
#  'grindavik',
#  'natal',
#  'muscat',
#  'tutoia',
#  'saint-augustin',
#  'cururupu',
#  'lushunkou',
#  'padang',
#  'marzuq',
#  'lolua',
#  'fujinomiya',
#  'kamenskoye',
#  'dzhebariki-khaya',
#  'ginir',
#  'tatawin',
#  'hecelchakan',
#  'hohen neuendorf',
#  'sobolevo',
#  'tabou',
#  'bartica',
#  'ishigaki',
#  'am timan',
#  'tongliao',
#  'sainte-marie',
#  'mezen',
#  'sabang',
#  'jumla',
#  'petropavlovsk-kamchatskiy',
#  'lachhmangarh',
#  'acapulco',
#  'imbituba',
#  'inverell',
#  'bereda',
#  'savannakhet',
#  'sakakah',
#  'dujuma',
#  'lanxi',
#  'romny',
#  'honiara',
#  'goderich',
#  'arlit',
#  'sorong',
#  'mareeba',
#  'isetskoye',
#  'manicore',
#  'miles city',
#  'yakeshi',
#  'saint-pierre',
#  'mwinilunga',
#  'orange cove',
#  'tefe',
#  'kletnya',
#  'skalistyy',
#  'rapid valley',
#  'ulloa',
#  'comodoro rivadavia',
#  'bestobe',
#  'hay river',
#  'chumphon',
#  'rorvik',
#  'oussouye',
#  'lander',
#  'inirida',
#  'zhangye',
#  'tondano',
#  'kalabo',
#  'atambua',
#  'quimper',
#  'ambulu',
#  'solovetskiy',
#  'rungata',
#  'pimenteiras',
#  'camopi']

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | vestmannaeyjar
# Processing Record 3 of Set 1 | cap malheureux
# Processing Record 4 of Set 1 | iberia
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | dolores
# Processing Record 7 of Set 1 | sao filipe
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | karratha
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | vardo
# Processing Record 12 of Set 1 | roebourne
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | westport
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | moerai
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | montepuez
# Processing Record 23 of Set 1 | lavrentiya
# Processing Record 24 of Set 1 | cairns
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | kajaani
# Processing Record 28 of Set 1 | yuganets
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | esperance
# Processing Record 31 of Set 1 | tshikapa
# Processing Record 32 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 1 | viedma
# Processing Record 34 of Set 1 | gornyy
# Processing Record 35 of Set 1 | coahuayana
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | klaksvik
# Processing Record 38 of Set 1 | constitucion
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | tyukhtet
# Processing Record 42 of Set 1 | kununurra
# Processing Record 43 of Set 1 | pisco
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | saint george
# Processing Record 46 of Set 1 | prieska
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | chapais
# Processing Record 49 of Set 1 | kasongo
# Processing Record 50 of Set 1 | klyuchi
# Processing Record 1 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | pangnirtung
# Processing Record 4 of Set 2 | udachnyy
# Processing Record 5 of Set 2 | jacareacanga
# Processing Record 6 of Set 2 | dabat
# Processing Record 7 of Set 2 | san cristobal
# Processing Record 8 of Set 2 | tahta
# Processing Record 9 of Set 2 | terney
# Processing Record 10 of Set 2 | hermanus
# Processing Record 11 of Set 2 | killybegs
# Processing Record 12 of Set 2 | mariinsk
# Processing Record 13 of Set 2 | port hardy
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | rincon
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | punta arenas
# Processing Record 18 of Set 2 | druzhba
# Processing Record 19 of Set 2 | maryborough
# Processing Record 20 of Set 2 | sao miguel do araguaia
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | kiunga
# Processing Record 23 of Set 2 | norman wells
# Processing Record 24 of Set 2 | lodwar
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | nikolskoye
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | namtsy
# Processing Record 30 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 2 | hanzhong
# Processing Record 32 of Set 2 | faya
# Processing Record 33 of Set 2 | bindi
# Processing Record 34 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 2 | gigmoto
# Processing Record 36 of Set 2 | vaini
# Processing Record 37 of Set 2 | broome
# Processing Record 38 of Set 2 | dholka
# Processing Record 39 of Set 2 | olafsvik
# Processing Record 40 of Set 2 | biak
# Processing Record 41 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | dukat
# Processing Record 44 of Set 2 | bandarbeyla
# Processing Record 45 of Set 2 | gorin
# Processing Record 46 of Set 2 | albany
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | sampues
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | riyadh
# Processing Record 1 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 3 | khorinsk
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | chute-aux-outardes
# Processing Record 5 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 3 | nyurba
# Processing Record 8 of Set 3 | buala
# Processing Record 9 of Set 3 | dwarka
# Processing Record 10 of Set 3 | busselton
# Processing Record 11 of Set 3 | tuktoyaktuk
# Processing Record 12 of Set 3 | lata
# Processing Record 13 of Set 3 | sabzevar
# Processing Record 14 of Set 3 | pevek
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 3 | barreirinha
# Processing Record 17 of Set 3 | westerland
# Processing Record 18 of Set 3 | saint anthony
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | boulsa
# Processing Record 21 of Set 3 | chikhli
# Processing Record 22 of Set 3 | hithadhoo
# Processing Record 23 of Set 3 | chernyshevskiy
# Processing Record 24 of Set 3 | kasempa
# Processing Record 25 of Set 3 | ahipara
# Processing Record 26 of Set 3 | pochutla
# Processing Record 27 of Set 3 | synya
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | chuy
# Processing Record 31 of Set 3 | ostrovnoy
# Processing Record 32 of Set 3 | bengkulu
# Processing Record 33 of Set 3 | iqaluit
# Processing Record 34 of Set 3 | camocim
# Processing Record 35 of Set 3 | hofn
# Processing Record 36 of Set 3 | mount isa
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | lebu
# Processing Record 39 of Set 3 | malakal
# Processing Record 40 of Set 3 | xiamen
# Processing Record 41 of Set 3 | salta
# Processing Record 42 of Set 3 | amahai
# Processing Record 43 of Set 3 | makakilo city
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | chornobayivka
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | sibolga
# Processing Record 48 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 3 | rawson
# Processing Record 50 of Set 3 | japura
# Processing Record 1 of Set 4 | yellowknife
# Processing Record 2 of Set 4 | barrow
# Processing Record 3 of Set 4 | natchez
# Processing Record 4 of Set 4 | okhotsk
# Processing Record 5 of Set 4 | qasigiannguit
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | ilulissat
# Processing Record 8 of Set 4 | moussoro
# Processing Record 9 of Set 4 | talaya
# Processing Record 10 of Set 4 | whitianga
# Processing Record 11 of Set 4 | sokol
# Processing Record 12 of Set 4 | saint-francois
# Processing Record 13 of Set 4 | cabatuan
# Processing Record 14 of Set 4 | raudeberg
# Processing Record 15 of Set 4 | mastic beach
# Processing Record 16 of Set 4 | guantanamo
# Processing Record 17 of Set 4 | leningradskiy
# Processing Record 18 of Set 4 | sokoto
# Processing Record 19 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 4 | deniliquin
# Processing Record 21 of Set 4 | ketchikan
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | khatanga
# Processing Record 24 of Set 4 | morondava
# Processing Record 25 of Set 4 | corum
# Processing Record 26 of Set 4 | slave lake
# Processing Record 27 of Set 4 | port elizabeth
# Processing Record 28 of Set 4 | dikson
# Processing Record 29 of Set 4 | nanakuli
# Processing Record 30 of Set 4 | bambous virieux
# Processing Record 31 of Set 4 | uyuni
# Processing Record 32 of Set 4 | nantucket
# Processing Record 33 of Set 4 | tiksi
# Processing Record 34 of Set 4 | solnechnogorsk
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | ulaangom
# Processing Record 38 of Set 4 | antofagasta
# Processing Record 39 of Set 4 | moroni
# Processing Record 40 of Set 4 | dingzhou
# Processing Record 41 of Set 4 | san rafael
# Processing Record 42 of Set 4 | verkh-usugli
# Processing Record 43 of Set 4 | nadapuram
# Processing Record 44 of Set 4 | mecca
# Processing Record 45 of Set 4 | hualmay
# Processing Record 46 of Set 4 | igarka
# Processing Record 47 of Set 4 | anchorage
# Processing Record 48 of Set 4 | miraflores
# Processing Record 49 of Set 4 | la paz
# Processing Record 50 of Set 4 | upernavik
# Processing Record 1 of Set 5 | ribeira grande
# Processing Record 2 of Set 5 | bilma
# Processing Record 3 of Set 5 | cabo san lucas
# Processing Record 4 of Set 5 | abu samrah
# Processing Record 5 of Set 5 | batagay-alyta
# Processing Record 6 of Set 5 | kaeo
# Processing Record 7 of Set 5 | tecolutla
# Processing Record 8 of Set 5 | huarmey
# Processing Record 9 of Set 5 | sept-iles
# Processing Record 10 of Set 5 | kudahuvadhoo
# Processing Record 11 of Set 5 | hambantota
# Processing Record 12 of Set 5 | champerico
# Processing Record 13 of Set 5 | hami
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | moundou
# Processing Record 16 of Set 5 | yuanping
# Processing Record 17 of Set 5 | hasaki
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 5 | tabas
# Processing Record 21 of Set 5 | akyab
# Processing Record 22 of Set 5 | kargopol
# Processing Record 23 of Set 5 | dharchula
# Processing Record 24 of Set 5 | jaguarao
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | kunda
# Processing Record 27 of Set 5 | bonavista
# Processing Record 28 of Set 5 | ewa beach
# Processing Record 29 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 30 of Set 5 | verkhnevilyuysk
# Processing Record 31 of Set 5 | osoyoos
# Processing Record 32 of Set 5 | warrington
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | kaitangata
# Processing Record 35 of Set 5 | bayangol
# Processing Record 36 of Set 5 | zenzeli
# Processing Record 37 of Set 5 | stornoway
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | novikovo
# Processing Record 40 of Set 5 | zarubino
# Processing Record 41 of Set 5 | poum
# Processing Record 42 of Set 5 | chokurdakh
# Processing Record 43 of Set 5 | veraval
# Processing Record 44 of Set 5 | zhengjiatun
# Processing Record 45 of Set 5 | krasnoselkup
# Processing Record 46 of Set 5 | yarovoye
# Processing Record 47 of Set 5 | koungou
# Processing Record 48 of Set 5 | anadyr
# Processing Record 49 of Set 5 | jashpurnagar
# Processing Record 50 of Set 5 | salalah
# Processing Record 1 of Set 6 | xiongzhou
# Processing Record 2 of Set 6 | tarm
# Processing Record 3 of Set 6 | acari
# Processing Record 4 of Set 6 | ancud
# Processing Record 5 of Set 6 | nelson bay
# Processing Record 6 of Set 6 | souillac
# Processing Record 7 of Set 6 | sur
# Processing Record 8 of Set 6 | luderitz
# Processing Record 9 of Set 6 | muros
# Processing Record 10 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 6 | tonota
# Processing Record 12 of Set 6 | porto-vecchio
# Processing Record 13 of Set 6 | santa isabel do rio negro
# Processing Record 14 of Set 6 | port said
# Processing Record 15 of Set 6 | faanui
# Processing Record 16 of Set 6 | koslan
# Processing Record 17 of Set 6 | sitka
# Processing Record 18 of Set 6 | shitanjing
# Processing Record 19 of Set 6 | bourail
# Processing Record 20 of Set 6 | namibe
# Processing Record 21 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 22 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 6 | nanortalik
# Processing Record 24 of Set 6 | ossora
# Processing Record 25 of Set 6 | inhambane
# Processing Record 26 of Set 6 | tilichiki
# Processing Record 27 of Set 6 | aklavik
# Processing Record 28 of Set 6 | saskylakh
# Processing Record 29 of Set 6 | ponta do sol
# Processing Record 30 of Set 6 | yining
# Processing Record 31 of Set 6 | ambilobe
# Processing Record 32 of Set 6 | bodden town
# Processing Record 33 of Set 6 | kralendijk
# Processing Record 34 of Set 6 | mahebourg
# Processing Record 35 of Set 6 | luba
# Processing Record 36 of Set 6 | guerrero negro
# Processing Record 37 of Set 6 | stonewall
# Processing Record 38 of Set 6 | poronaysk
# Processing Record 39 of Set 6 | avera
# Processing Record 40 of Set 6 | tessalit
# Processing Record 41 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 42 of Set 6 | pacific grove
# Processing Record 43 of Set 6 | cambe
# Processing Record 44 of Set 6 | novovasylivka
# Processing Record 45 of Set 6 | harqalah
# Processing Record 46 of Set 6 | luganville
# Processing Record 47 of Set 6 | victoria
# Processing Record 48 of Set 6 | abeche
# Processing Record 49 of Set 6 | camacupa
# Processing Record 50 of Set 6 | port-gentil
# Processing Record 1 of Set 7 | uige
# Processing Record 2 of Set 7 | qaqortoq
# Processing Record 3 of Set 7 | eyl
# Processing Record 4 of Set 7 | mackay
# Processing Record 5 of Set 7 | gushi
# Processing Record 6 of Set 7 | dingle
# Processing Record 7 of Set 7 | port blair
# Processing Record 8 of Set 7 | lesnoy
# Processing Record 9 of Set 7 | nabire
# Processing Record 10 of Set 7 | talovaya
# Processing Record 11 of Set 7 | mana
# Processing Record 12 of Set 7 | tromso
# Processing Record 13 of Set 7 | traverse city
# Processing Record 14 of Set 7 | antalaha
# Processing Record 15 of Set 7 | northam
# Processing Record 16 of Set 7 | roma
# Processing Record 17 of Set 7 | bathsheba
# Processing Record 18 of Set 7 | gizo
# Processing Record 19 of Set 7 | bad doberan
# Processing Record 20 of Set 7 | troitsko-pechorsk
# Processing Record 21 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 22 of Set 7 | campbell river
# Processing Record 23 of Set 7 | kieta
# Processing Record 24 of Set 7 | aginskoye
# Processing Record 25 of Set 7 | karlskoga
# Processing Record 26 of Set 7 | neustadt
# Processing Record 27 of Set 7 | benguela
# Processing Record 28 of Set 7 | corrente
# Processing Record 29 of Set 7 | saint-philippe
# Processing Record 30 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 7 | bakchar
# Processing Record 32 of Set 7 | xinmin
# Processing Record 33 of Set 7 | tenenkou
# Processing Record 34 of Set 7 | prien
# Processing Record 35 of Set 7 | turukhansk
# Processing Record 36 of Set 7 | hirara
# Processing Record 37 of Set 7 | kutum
# Processing Record 38 of Set 7 | dunedin
# Processing Record 39 of Set 7 | san matias
# Processing Record 40 of Set 7 | ternate
# Processing Record 41 of Set 7 | lere
# Processing Record 42 of Set 7 | vestmanna
# Processing Record 43 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 44 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 7 | iracoubo
# Processing Record 46 of Set 7 | manzanillo
# Processing Record 47 of Set 7 | ariquemes
# Processing Record 48 of Set 7 | vieux-habitants
# Processing Record 49 of Set 7 | manta
# Processing Record 50 of Set 7 | najran
# Processing Record 1 of Set 8 | sao felix do xingu
# Processing Record 2 of Set 8 | isiro
# Processing Record 3 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 4 of Set 8 | portland
# Processing Record 5 of Set 8 | brae
# Processing Record 6 of Set 8 | aljezur
# Processing Record 7 of Set 8 | miri
# Processing Record 8 of Set 8 | gondanglegi
# Processing Record 9 of Set 8 | kurilsk
# Processing Record 10 of Set 8 | papasquiaro
# City not found. Skipping...
# Processing Record 11 of Set 8 | ludvika
# Processing Record 12 of Set 8 | aykhal
# Processing Record 13 of Set 8 | kholm-zhirkovskiy
# Processing Record 14 of Set 8 | ferme-neuve
# Processing Record 15 of Set 8 | sinnamary
# Processing Record 16 of Set 8 | lorengau
# Processing Record 17 of Set 8 | plettenberg bay
# Processing Record 18 of Set 8 | ribeira brava
# Processing Record 19 of Set 8 | sembakung
# Processing Record 20 of Set 8 | punakha
# Processing Record 21 of Set 8 | tahe
# Processing Record 22 of Set 8 | palmer
# Processing Record 23 of Set 8 | auxerre
# Processing Record 24 of Set 8 | bilibino
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | jijiang
# Processing Record 27 of Set 8 | yar-sale
# Processing Record 28 of Set 8 | kawalu
# Processing Record 29 of Set 8 | tapaua
# City not found. Skipping...
# Processing Record 30 of Set 8 | provideniya
# Processing Record 31 of Set 8 | wattegama
# Processing Record 32 of Set 8 | sao joao da barra
# Processing Record 33 of Set 8 | awbari
# Processing Record 34 of Set 8 | los llanos de aridane
# Processing Record 35 of Set 8 | dossor
# Processing Record 36 of Set 8 | vila velha
# Processing Record 37 of Set 8 | ngunguru
# Processing Record 38 of Set 8 | banjar
# Processing Record 39 of Set 8 | komsomolskiy
# Processing Record 40 of Set 8 | arman
# Processing Record 41 of Set 8 | presidencia roque saenz pena
# Processing Record 42 of Set 8 | mangrol
# Processing Record 43 of Set 8 | camana
# Processing Record 44 of Set 8 | margate
# Processing Record 45 of Set 8 | beringovskiy
# Processing Record 46 of Set 8 | valparaiso
# Processing Record 47 of Set 8 | garowe
# Processing Record 48 of Set 8 | pringsewu
# Processing Record 49 of Set 8 | mujiayingzi
# Processing Record 50 of Set 8 | itarema
# Processing Record 1 of Set 9 | condoto
# Processing Record 2 of Set 9 | acajutla
# Processing Record 3 of Set 9 | abu kamal
# Processing Record 4 of Set 9 | shihezi
# Processing Record 5 of Set 9 | burgos
# Processing Record 6 of Set 9 | isangel
# Processing Record 7 of Set 9 | xining
# Processing Record 8 of Set 9 | ouesso
# Processing Record 9 of Set 9 | chicama
# Processing Record 10 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | lagoa
# Processing Record 12 of Set 9 | puerto leguizamo
# Processing Record 13 of Set 9 | gladstone
# Processing Record 14 of Set 9 | yulara
# Processing Record 15 of Set 9 | alofi
# Processing Record 16 of Set 9 | concepcion del oro
# Processing Record 17 of Set 9 | praya
# Processing Record 18 of Set 9 | touros
# Processing Record 19 of Set 9 | oga
# Processing Record 20 of Set 9 | sovetskaya
# Processing Record 21 of Set 9 | mungaa
# Processing Record 22 of Set 9 | dibaya
# City not found. Skipping...
# Processing Record 23 of Set 9 | careiro da varzea
# Processing Record 24 of Set 9 | baykit
# Processing Record 25 of Set 9 | burnie
# Processing Record 26 of Set 9 | wanning
# Processing Record 27 of Set 9 | tiarei
# Processing Record 28 of Set 9 | shingu
# Processing Record 29 of Set 9 | nagato
# Processing Record 30 of Set 9 | teya
# Processing Record 31 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 9 | paka
# Processing Record 33 of Set 9 | rio grande
# Processing Record 34 of Set 9 | dhidhdhoo
# Processing Record 35 of Set 9 | muli
# Processing Record 36 of Set 9 | samarinda
# Processing Record 37 of Set 9 | hikari
# Processing Record 38 of Set 9 | poggibonsi
# Processing Record 39 of Set 9 | bulgan
# Processing Record 40 of Set 9 | juifang
# City not found. Skipping...
# Processing Record 41 of Set 9 | arroyo
# Processing Record 42 of Set 9 | kazanskoye
# Processing Record 43 of Set 9 | mariinskiy posad
# Processing Record 44 of Set 9 | kerman
# Processing Record 45 of Set 9 | kirakira
# Processing Record 46 of Set 9 | sisimiut
# Processing Record 47 of Set 9 | kapoeta
# Processing Record 48 of Set 9 | clyde river
# Processing Record 49 of Set 9 | lodja
# Processing Record 50 of Set 9 | jinchang
# Processing Record 1 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 2 of Set 10 | revelganj
# Processing Record 3 of Set 10 | macatbong
# Processing Record 4 of Set 10 | moyale
# Processing Record 5 of Set 10 | madridejos
# Processing Record 6 of Set 10 | zhongshu
# Processing Record 7 of Set 10 | puerto carreno
# Processing Record 8 of Set 10 | itupiranga
# Processing Record 9 of Set 10 | hamilton
# Processing Record 10 of Set 10 | la rioja
# Processing Record 11 of Set 10 | half moon bay
# Processing Record 12 of Set 10 | launceston
# Processing Record 13 of Set 10 | teknaf
# Processing Record 14 of Set 10 | seymchan
# Processing Record 15 of Set 10 | port hedland
# Processing Record 16 of Set 10 | jiuquan
# Processing Record 17 of Set 10 | upata
# Processing Record 18 of Set 10 | porto novo
# Processing Record 19 of Set 10 | bealanana
# Processing Record 20 of Set 10 | sioux lookout
# Processing Record 21 of Set 10 | tula
# Processing Record 22 of Set 10 | montrose
# Processing Record 23 of Set 10 | toumodi
# Processing Record 24 of Set 10 | galesong
# Processing Record 25 of Set 10 | yambio
# Processing Record 26 of Set 10 | korla
# Processing Record 27 of Set 10 | wilmington
# Processing Record 28 of Set 10 | strezhevoy
# Processing Record 29 of Set 10 | riyaq
# City not found. Skipping...
# Processing Record 30 of Set 10 | fukue
# Processing Record 31 of Set 10 | hargeysa
# Processing Record 32 of Set 10 | esso
# Processing Record 33 of Set 10 | chippewa falls
# Processing Record 34 of Set 10 | hermosillo
# Processing Record 35 of Set 10 | bayan
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | richards bay
# Processing Record 38 of Set 10 | znamenskoye
# Processing Record 39 of Set 10 | alcala de henares
# Processing Record 40 of Set 10 | trelew
# Processing Record 41 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 42 of Set 10 | muisne
# Processing Record 43 of Set 10 | codrington
# Processing Record 44 of Set 10 | usakos
# Processing Record 45 of Set 10 | szczecinek
# Processing Record 46 of Set 10 | yashkul
# Processing Record 47 of Set 10 | te anau
# Processing Record 48 of Set 10 | pleasant point
# Processing Record 49 of Set 10 | nauen
# Processing Record 50 of Set 10 | san martin
# Processing Record 1 of Set 11 | praia
# Processing Record 2 of Set 11 | mocajuba
# Processing Record 3 of Set 11 | pascagoula
# Processing Record 4 of Set 11 | salo
# Processing Record 5 of Set 11 | semiletka
# Processing Record 6 of Set 11 | navapur
# City not found. Skipping...
# Processing Record 7 of Set 11 | longyan
# Processing Record 8 of Set 11 | walvis bay
# Processing Record 9 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 11 | sechura
# Processing Record 11 of Set 11 | khandyga
# Processing Record 12 of Set 11 | blagoyevo
# Processing Record 13 of Set 11 | bodaybo
# Processing Record 14 of Set 11 | talas
# Processing Record 15 of Set 11 | yola
# Processing Record 16 of Set 11 | micheweni
# Processing Record 17 of Set 11 | albion
# Processing Record 18 of Set 11 | port augusta
# Processing Record 19 of Set 11 | saveh
# Processing Record 20 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 11 | texas city
# Processing Record 22 of Set 11 | anahuac
# Processing Record 23 of Set 11 | chara
# Processing Record 24 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 25 of Set 11 | san quintin
# Processing Record 26 of Set 11 | phangnga
# Processing Record 27 of Set 11 | pemba
# Processing Record 28 of Set 11 | dianopolis
# City not found. Skipping...
# Processing Record 29 of Set 11 | barcelos
# Processing Record 30 of Set 11 | tucuman
# Processing Record 31 of Set 11 | soeng sang
# Processing Record 32 of Set 11 | kanth
# Processing Record 33 of Set 11 | amapa
# Processing Record 34 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 35 of Set 11 | bara
# Processing Record 36 of Set 11 | yusva
# City not found. Skipping...
# Processing Record 37 of Set 11 | san patricio
# Processing Record 38 of Set 11 | honolulu
# Processing Record 39 of Set 11 | tuatapere
# Processing Record 40 of Set 11 | mahajanga
# Processing Record 41 of Set 11 | vitoria da conquista
# Processing Record 42 of Set 11 | two rivers
# Processing Record 43 of Set 11 | bogotol
# Processing Record 44 of Set 11 | griffith
# Processing Record 45 of Set 11 | ahuimanu
# Processing Record 46 of Set 11 | bindura
# Processing Record 47 of Set 11 | independencia
# Processing Record 48 of Set 11 | auki
# Processing Record 49 of Set 11 | aksu
# Processing Record 50 of Set 11 | fakel
# Processing Record 1 of Set 12 | imeni poliny osipenko
# Processing Record 2 of Set 12 | umm jarr
# City not found. Skipping...
# Processing Record 3 of Set 12 | alice springs
# Processing Record 4 of Set 12 | srednekolymsk
# Processing Record 5 of Set 12 | smolenka
# Processing Record 6 of Set 12 | rio de jesus
# Processing Record 7 of Set 12 | ciudad bolivar
# Processing Record 8 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 12 | cabra
# Processing Record 10 of Set 12 | skjervoy
# Processing Record 11 of Set 12 | redlands
# Processing Record 12 of Set 12 | bondo
# Processing Record 13 of Set 12 | barmer
# Processing Record 14 of Set 12 | lasa
# Processing Record 15 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 12 | south river
# Processing Record 17 of Set 12 | vryburg
# Processing Record 18 of Set 12 | obidos
# Processing Record 19 of Set 12 | tulum
# Processing Record 20 of Set 12 | sayyan
# Processing Record 21 of Set 12 | alekseyevsk
# Processing Record 22 of Set 12 | nome
# Processing Record 23 of Set 12 | bodo
# Processing Record 24 of Set 12 | kemijarvi
# Processing Record 25 of Set 12 | roald
# Processing Record 26 of Set 12 | kloulklubed
# Processing Record 27 of Set 12 | lokosovo
# Processing Record 28 of Set 12 | hokitika
# Processing Record 29 of Set 12 | miramar
# Processing Record 30 of Set 12 | malm
# Processing Record 31 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 32 of Set 12 | maniitsoq
# Processing Record 33 of Set 12 | qeshm
# Processing Record 34 of Set 12 | ust-nera
# Processing Record 35 of Set 12 | dudinka
# Processing Record 36 of Set 12 | fierze
# City not found. Skipping...
# Processing Record 37 of Set 12 | flin flon
# Processing Record 38 of Set 12 | cervo
# Processing Record 39 of Set 12 | ponta delgada
# Processing Record 40 of Set 12 | hobyo
# Processing Record 41 of Set 12 | perth
# Processing Record 42 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 43 of Set 12 | bubaque
# Processing Record 44 of Set 12 | nishihara
# Processing Record 45 of Set 12 | freeport
# Processing Record 46 of Set 12 | sertolovo
# Processing Record 47 of Set 12 | kamenka
# Processing Record 48 of Set 12 | caceres
# Processing Record 49 of Set 12 | tynda
# Processing Record 50 of Set 12 | sakaiminato
# Processing Record 1 of Set 13 | thinadhoo
# Processing Record 2 of Set 13 | enshi
# Processing Record 3 of Set 13 | nasrullaganj
# City not found. Skipping...
# Processing Record 4 of Set 13 | pandan
# Processing Record 5 of Set 13 | manica
# Processing Record 6 of Set 13 | lidkoping
# Processing Record 7 of Set 13 | jaguaruna
# Processing Record 8 of Set 13 | bowen
# Processing Record 9 of Set 13 | saldanha
# Processing Record 10 of Set 13 | villarrica
# Processing Record 11 of Set 13 | umm lajj
# Processing Record 12 of Set 13 | coquimbo
# Processing Record 13 of Set 13 | zakopane
# Processing Record 14 of Set 13 | nakhon thai
# Processing Record 15 of Set 13 | mordovo
# Processing Record 16 of Set 13 | sinop
# Processing Record 17 of Set 13 | prigorodnyy
# Processing Record 18 of Set 13 | taltal
# Processing Record 19 of Set 13 | boffa
# Processing Record 20 of Set 13 | peleduy
# Processing Record 21 of Set 13 | thunder bay
# Processing Record 22 of Set 13 | necochea
# Processing Record 23 of Set 13 | zakamensk
# Processing Record 24 of Set 13 | dongsheng
# Processing Record 25 of Set 13 | rio de janeiro
# Processing Record 26 of Set 13 | bosaso
# Processing Record 27 of Set 13 | vila franca do campo
# Processing Record 28 of Set 13 | booue
# Processing Record 29 of Set 13 | mantua
# Processing Record 30 of Set 13 | the valley
# Processing Record 31 of Set 13 | caucaia
# Processing Record 32 of Set 13 | shubarshi
# Processing Record 33 of Set 13 | atbasar
# Processing Record 34 of Set 13 | trairi
# Processing Record 35 of Set 13 | port macquarie
# Processing Record 36 of Set 13 | saint joseph
# Processing Record 37 of Set 13 | jati
# Processing Record 38 of Set 13 | oranjemund
# Processing Record 39 of Set 13 | soyo
# Processing Record 40 of Set 13 | jalingo
# Processing Record 41 of Set 13 | kiomboi
# Processing Record 42 of Set 13 | mehamn
# Processing Record 43 of Set 13 | fort nelson
# Processing Record 44 of Set 13 | athabasca
# Processing Record 45 of Set 13 | makhachkala
# Processing Record 46 of Set 13 | canakkale
# Processing Record 47 of Set 13 | nizwa
# Processing Record 48 of Set 13 | lazaro cardenas
# Processing Record 49 of Set 13 | fulitun
# City not found. Skipping...
# Processing Record 50 of Set 13 | ayabaca
# Processing Record 1 of Set 14 | paamiut
# Processing Record 2 of Set 14 | chiredzi
# Processing Record 3 of Set 14 | nouadhibou
# Processing Record 4 of Set 14 | cockburn town
# Processing Record 5 of Set 14 | katsuura
# Processing Record 6 of Set 14 | hervey bay
# Processing Record 7 of Set 14 | sokolovo
# Processing Record 8 of Set 14 | rancho palos verdes
# Processing Record 9 of Set 14 | taoudenni
# Processing Record 10 of Set 14 | zlatoustovsk
# City not found. Skipping...
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | katangli
# Processing Record 13 of Set 14 | maralal
# Processing Record 14 of Set 14 | daru
# Processing Record 15 of Set 14 | sabha
# Processing Record 16 of Set 14 | inderborskiy
# City not found. Skipping...
# Processing Record 17 of Set 14 | san juan
# Processing Record 18 of Set 14 | sarangani
# Processing Record 19 of Set 14 | newport
# Processing Record 20 of Set 14 | miyako
# Processing Record 21 of Set 14 | rocha
# Processing Record 22 of Set 14 | colac
# Processing Record 23 of Set 14 | nago
# Processing Record 24 of Set 14 | mizpe ramon
# City not found. Skipping...
# Processing Record 25 of Set 14 | fez
# Processing Record 26 of Set 14 | kankon
# Processing Record 27 of Set 14 | mao
# Processing Record 28 of Set 14 | mandurah
# Processing Record 29 of Set 14 | kasane
# Processing Record 30 of Set 14 | camacha
# Processing Record 31 of Set 14 | ozernovskiy
# Processing Record 32 of Set 14 | abu dhabi
# Processing Record 33 of Set 14 | coromandel
# Processing Record 34 of Set 14 | canto do buriti
# Processing Record 35 of Set 14 | ambon
# Processing Record 36 of Set 14 | kantabanji
# Processing Record 37 of Set 14 | narsaq
# Processing Record 38 of Set 14 | ulladulla
# Processing Record 39 of Set 14 | bac lieu
# Processing Record 40 of Set 14 | buenos aires
# Processing Record 41 of Set 14 | piranshahr
# Processing Record 42 of Set 14 | banepa
# Processing Record 43 of Set 14 | bardiyah
# Processing Record 44 of Set 14 | morant bay
# Processing Record 45 of Set 14 | ardabil
# Processing Record 46 of Set 14 | grindavik
# Processing Record 47 of Set 14 | natal
# Processing Record 48 of Set 14 | muscat
# Processing Record 49 of Set 14 | tutoia
# Processing Record 50 of Set 14 | saint-augustin
# Processing Record 1 of Set 15 | cururupu
# Processing Record 2 of Set 15 | lushunkou
# City not found. Skipping...
# Processing Record 3 of Set 15 | padang
# Processing Record 4 of Set 15 | marzuq
# Processing Record 5 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 6 of Set 15 | fujinomiya
# Processing Record 7 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 15 | dzhebariki-khaya
# Processing Record 9 of Set 15 | ginir
# Processing Record 10 of Set 15 | tatawin
# Processing Record 11 of Set 15 | hecelchakan
# Processing Record 12 of Set 15 | hohen neuendorf
# Processing Record 13 of Set 15 | sobolevo
# Processing Record 14 of Set 15 | tabou
# Processing Record 15 of Set 15 | bartica
# Processing Record 16 of Set 15 | ishigaki
# Processing Record 17 of Set 15 | am timan
# Processing Record 18 of Set 15 | tongliao
# Processing Record 19 of Set 15 | sainte-marie
# Processing Record 20 of Set 15 | mezen
# Processing Record 21 of Set 15 | sabang
# Processing Record 22 of Set 15 | jumla
# Processing Record 23 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 15 | lachhmangarh
# Processing Record 25 of Set 15 | acapulco
# Processing Record 26 of Set 15 | imbituba
# Processing Record 27 of Set 15 | inverell
# Processing Record 28 of Set 15 | bereda
# Processing Record 29 of Set 15 | savannakhet
# Processing Record 30 of Set 15 | sakakah
# Processing Record 31 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 32 of Set 15 | lanxi
# Processing Record 33 of Set 15 | romny
# Processing Record 34 of Set 15 | honiara
# Processing Record 35 of Set 15 | goderich
# Processing Record 36 of Set 15 | arlit
# Processing Record 37 of Set 15 | sorong
# Processing Record 38 of Set 15 | mareeba
# Processing Record 39 of Set 15 | isetskoye
# Processing Record 40 of Set 15 | manicore
# Processing Record 41 of Set 15 | miles city
# Processing Record 42 of Set 15 | yakeshi
# Processing Record 43 of Set 15 | saint-pierre
# Processing Record 44 of Set 15 | mwinilunga
# Processing Record 45 of Set 15 | orange cove
# Processing Record 46 of Set 15 | tefe
# Processing Record 47 of Set 15 | kletnya
# Processing Record 48 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 49 of Set 15 | rapid valley
# Processing Record 50 of Set 15 | ulloa
# Processing Record 1 of Set 16 | comodoro rivadavia
# Processing Record 2 of Set 16 | bestobe
# Processing Record 3 of Set 16 | hay river
# Processing Record 4 of Set 16 | chumphon
# Processing Record 5 of Set 16 | rorvik
# Processing Record 6 of Set 16 | oussouye
# Processing Record 7 of Set 16 | lander
# Processing Record 8 of Set 16 | inirida
# Processing Record 9 of Set 16 | zhangye
# Processing Record 10 of Set 16 | tondano
# Processing Record 11 of Set 16 | kalabo
# Processing Record 12 of Set 16 | atambua
# Processing Record 13 of Set 16 | quimper
# Processing Record 14 of Set 16 | ambulu
# Processing Record 15 of Set 16 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 16 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 16 | pimenteiras
# Processing Record 18 of Set 16 | camopi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
city_data_df.head(-10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Rikitea      PF -23.1203 -134.9692     73.04        78
# 1    Vestmannaeyjar      IS  63.4427  -20.2734     52.79        82
# 2    Cap Malheureux      MU -19.9842   57.6142     71.47        69
# 3            Iberia      US  29.9502  -91.7507     82.98        89
# 4             Bluff      NZ -46.6000  168.3333     45.81        87
# ..              ...     ...      ...       ...       ...       ...
# 696         Bestobe      KZ  52.4994   73.0975     49.14        65
# 697       Hay River      CA  60.8156 -115.7999     55.38        82
# 698        Chumphon      TH  10.3333   98.8333     71.98        96
# 699          Rorvik      NO  64.8621   11.2373     55.51        82
# 700        Oussouye      SN  12.4850  -16.5469     91.58        68
#
#      Cloudiness  Wind Speed Current Description
# 0            96        8.12     overcast clouds
# 1            40       12.66    scattered clouds
# 2             5        5.99           clear sky
# 3             1        4.61           clear sky
# 4           100       28.36     overcast clouds
# ..          ...         ...                 ...
# 696          43        9.40    scattered clouds
# 697          75        6.91       broken clouds
# 698         100        9.91     overcast clouds
# 699          75       10.36          light rain
# 700          74        8.99       broken clouds
#
# [701 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
